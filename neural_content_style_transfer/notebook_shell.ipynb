# %%
from google.colab import drive
drive.mount('/content/drive')
gpu = !nvidia-smi -L
print(gpu[0])
import sys
sys.path.append('/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script')
      
import helper_functions
import NCTS
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# GPU 0: Tesla T4 (UUID: GPU-7e368162-917e-9ad7-e7b6-5e9a06be7ea8)

# %%
NCTS = NCTS.NCTS(steps=5000)
NCTS.perform_ncts("/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_art/Katze.png","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_fashion/0744.jpg","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_tshirt_masks/0744.png",show_every=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-46b4cb0ba1d2> in <module>()
# ----> 1 NCTS = NCTS.NCTS(steps=5000)
#       2 NCTS.perform_ncts("/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_art/Katze.png","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_fashion/0744.jpg","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_tshirt_masks/0744.png",show_every=1000)
#
# TypeError: __init__() got an unexpected keyword argument 'steps'

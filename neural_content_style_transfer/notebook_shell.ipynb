# %%
from google.colab import drive
drive.mount('/content/drive')
gpu = !nvidia-smi -L
print(gpu[0])
import sys
sys.path.append('/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script')
      
import helper_functions
import NCTS_adapted_for_GS
import matplotlib.pyplot as plt

# %% [markdown]
# style_layers_and_style_weights={
#             "conv1_1": 1.0,
#             "conv2_1": 0.75,
#             "conv3_1": 0.2,
#             "conv4_1": 0.2,
#             "conv5_1": 0.2,
#         },
#         content_layer="conv4_2",
#         content_fashion_weight=0.5,
#         content_art_weight=10,
#         style_art_weight=1e6,
#         steps=2000,
#         learning_rate=0.03,
#         show_every=100
#
# art_image_path="mock_data/images_art/Katze.png",
#         fashion_image_path="mock_data/images_fashion/0744.jpg",
#         fashion_mask_path="mock_data/images_tshirt_masks/0744.png"

# %%
NCTS = NCTS_adapted_for_GS.NCTS(style_layers_and_style_weights={
            "conv1_1": 1.0,
            "conv2_1": 0.75,
            "conv3_1": 0.2,
            "conv4_1": 0.2,
            "conv5_1": 0.2,
        },
        content_layer="conv4_2",
        content_fashion_weight=0.5,
        content_art_weight=10,
        style_art_weight=1e6,
        steps=300,
        learning_rate=0.03,
        show_every=100,
        white_canvas=True,
        fashion_image_feature_is_white=False)
images = NCTS.perform_ncts("/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_art/Katze.png","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_fashion/0744.jpg","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_tshirt_masks/0744.png")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d28eb279ec69> in <module>()
#      15         white_canvas=True,
#      16         fashion_image_feature_is_white=False)
# ---> 17 images = NCTS.perform_ncts("/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_art/Katze.png","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_fashion/0744.jpg","/content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/mock_data/images_tshirt_masks/0744.png")
#
# /content/drive/Othercomputers/MacBook/github/ArtXFashion/neural_content_style_transfer/NCTS_script/NCTS_adapted_for_GS.py in perform_ncts(self, art_image_path, fashion_image_path, fashion_mask_path)
#     231             fashion_image_features,
# ...

# %%
#for image in images:
plt.imshow(images[0])
